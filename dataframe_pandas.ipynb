# %%
import pandas as pd

# %%
serie = pd.Series([11, 12, 15, 14, 13, 12, 16, 10, 11, 13, 14])

# %% [raw]
# serie

# %%
print(serie)
# Out:
# 0     11
# 1     12
# 2     15
# 3     14
# 4     13
# 5     12
# 6     16
# 7     10
# 8     11
# 9     13
# 10    14
# dtype: int64

# %%
serie = pd.Series([11, 12, 15, 14, 13, 12, 16, 10, 11, 13, 14], index=["Anne", "marc", "normand", "julie", "alex", "Nathalie", "Marie", "Joe", "bob", "Eric", "Luc"])

# %%
print(serie)
# Out:
# Anne        11
# marc        12
# normand     15
# julie       14
# alex        13
# Nathalie    12
# Marie       16
# Joe         10
# bob         11
# Eric        13
# Luc         14
# dtype: int64

# %%
serie.describe()
# Out:
# count    11.000000
# mean     12.818182
# std       1.834022
# min      10.000000
# 25%      11.500000
# 50%      13.000000
# 75%      14.000000
# max      16.000000
# dtype: float64

# %%
serie["marc"]
# Out:
# 12

# %%
serie[1]
# Out:
# 12

# %%
serie[["Anne", "marc", "normand"]]
# Out:
# Anne       11
# marc       12
# normand    15
# dtype: int64

# %%
serie[serie[:]>12]
# Out:
# normand    15
# julie      14
# alex       13
# Marie      16
# Eric       13
# Luc        14
# dtype: int64

# %%
serie[serie>12]
# Out:
# normand    15
# julie      14
# alex       13
# Marie      16
# Eric       13
# Luc        14
# dtype: int64

# %%
import numpy as np

# %%
houses = np.genfromtxt("Houses.csv", delimiter=",", dtype=int)

# %%
df = pd.DataFrame(houses, columns=["Prix", "Taille de la maison", "Taille du terrain"])

# %%
df
# Out:
#       Prix  Taille de la maison  Taille du terrain
# 0   212000                 4148              25264
# 1   230000                 2501              11891
# 2   339000                 4374              25351
# 3   289000                 2398              22215
# 4   160000                 2536               9234
# 5    85000                 2368              13329
# 6    85000                 1264               8407
# 7   145000                 1572              12588
# 8   164000                 2375              16204
# 9   123500                 1161               9626
# 10  180000                 1542               8755
# 11  159500                 1464              14636
# 12  156000                 2240              21780
# 13  146500                 1269              11250
# 14  101500                  924               7361
# 15  109800                  768              10497
# 16  182000                 1320              15768
# ...

# %%
groupe1 = pd.Series([11, 12, 15, 14, 13, 12, 16, 10, 11, 13, 14], index=["Anne", "marc", "normand", "julie", "alex", "Nathalie", "Marie", "Joe", "bob", "Eric", "Luc"])

# %%
groupe1
# Out:
# Anne        11
# marc        12
# normand     15
# julie       14
# alex        13
# Nathalie    12
# Marie       16
# Joe         10
# bob         11
# Eric        13
# Luc         14
# dtype: int64

# %%
groupe2 = pd.Series([15, 11, 14, 11, 13, 12, 14, 14, 11, 13, 14], index=["Pol", "Yan", "Noah", "May", "Jose", "Nathalie", "Hubert", "Fred", "bob", "Eric", "Luc"])

# %%
groupe1
# Out:
# Anne        11
# marc        12
# normand     15
# julie       14
# alex        13
# Nathalie    12
# Marie       16
# Joe         10
# bob         11
# Eric        13
# Luc         14
# dtype: int64

# %%
groupe2
# Out:
# Pol         15
# Alex        11
# Noah        14
# May         11
# Jose        13
# Nathalie    12
# Hubert      14
# Fred        14
# bob         11
# Eric        13
# Luc         14
# dtype: int64

# %%
df2 = pd.DataFrame({"Groupe1":groupe1, "Groupe2":groupe2})

# %%
df2
# Out:
#           Groupe1  Groupe2
# Alex          NaN     11.0
# Anne         11.0      NaN
# Eric         13.0     13.0
# Fred          NaN     14.0
# Hubert        NaN     14.0
# Joe          10.0      NaN
# Jose          NaN     13.0
# Luc          14.0     14.0
# Marie        16.0      NaN
# May           NaN     11.0
# Nathalie     12.0     12.0
# Noah          NaN     14.0
# Pol           NaN     15.0
# alex         13.0      NaN
# bob          11.0     11.0
# julie        14.0      NaN
# marc         12.0      NaN
# normand      15.0      NaN

# %%
df3 = pd.read_table("googleplaystore.csv", sep=",")
df3
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df3 = df3.set_index("App")

# %%
df3
# Out:
#                                                                Category  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook           ART_AND_DESIGN
# Coloring book moana                                      ART_AND_DESIGN
# U Launcher Lite – FREE Live Cool Themes, Hide Apps       ART_AND_DESIGN
# Sketch - Draw & Paint                                    ART_AND_DESIGN
# Pixel Draw - Number Art Coloring Book                    ART_AND_DESIGN
# ...                                                                 ...
# Sya9a Maroc - FR                                                 FAMILY
# Fr. Mike Schmitz Audio Teachings                                 FAMILY
# Parkinson Exercices FR                                          MEDICAL
# The SCP Foundation DB fr nn5n                       BOOKS_AND_REFERENCE
# iHoroscope - 2018 Daily Horoscope & Astrology                 LIFESTYLE
#
#                                                     Rating Reviews  \
# App
# ...

# %%
df3.iloc[4, 3]
# Out:
# '2.8M'

# %%
df3.loc["Pixel Draw - Number Art Coloring Book"]
# Out:
# Category                   ART_AND_DESIGN
# Rating                                4.3
# Reviews                               967
# Size                                 2.8M
# Installs                         100,000+
# Type                                 Free
# Price                                   0
# Content Rating                   Everyone
# Genres            Art & Design;Creativity
# Last Updated                June 20, 2018
# Current Ver                           1.1
# Android Ver                    4.4 and up
# Name: Pixel Draw - Number Art Coloring Book, dtype: object

# %%
result = df3.loc["Pixel Draw - Number Art Coloring Book"]

# %%
result["Size"]
# Out:
# '2.8M'

# %%
df3.loc["Udemy - Online Courses",:]
# Out:
#                          Category  Rating Reviews Size    Installs  Type  \
# App
# Udemy - Online Courses  EDUCATION     4.5   99020  18M  1,000,000+  Free
# Udemy - Online Courses  EDUCATION     4.5   99020  18M  1,000,000+  Free
# Udemy - Online Courses  EDUCATION     4.5   99020  18M  1,000,000+  Free
#
#                        Price Content Rating     Genres    Last Updated  \
# App
# Udemy - Online Courses     0       Everyone  Education  August 2, 2018
# Udemy - Online Courses     0       Everyone  Education  August 2, 2018
# Udemy - Online Courses     0       Everyone  Education  August 2, 2018
#
#                        Current Ver Android Ver
# App
# Udemy - Online Courses       5.0.4  5.0 and up
# Udemy - Online Courses       5.0.4  5.0 and up
# Udemy - Online Courses       5.0.4  5.0 and up

# %%
df3.iloc[0:4,[0, 3, 5]]
# Out:
#                                                           Category  Size  Type
# App
# Photo Editor & Candy Camera & Grid & ScrapBook      ART_AND_DESIGN   19M  Free
# Coloring book moana                                 ART_AND_DESIGN   14M  Free
# U Launcher Lite – FREE Live Cool Themes, Hide Apps  ART_AND_DESIGN  8.7M  Free
# Sketch - Draw & Paint                               ART_AND_DESIGN   25M  Free

# %%
df3[df3["Category"]=="EDUCATION"]
# Out:
#                                                      Category  Rating  \
# App
# Duolingo: Learn Languages Free                      EDUCATION     4.7
# TED                                                 EDUCATION     4.6
# English Communication - Learn English for Chine...  EDUCATION     4.7
# Khan Academy                                        EDUCATION     4.6
# Learn English with Wlingua                          EDUCATION     4.7
# ...                                                       ...     ...
# Blinkist - Nonfiction Books                         EDUCATION     4.1
# Sago Mini Hat Maker                                 EDUCATION     4.9
# Fuzzy Numbers: Pre-K Number Foundation              EDUCATION     4.7
# Toca Life: City                                     EDUCATION     4.7
# Toca Life: Hospital                                 EDUCATION     4.7
#
#                                                     Reviews  \
# App
# ...

# %%
df3.shape
# Out:
# (10841, 12)

# %%
df3.columns
# Out:
# Index(['Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price',
#        'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df3["Rating"]
# Out:
# App
# Photo Editor & Candy Camera & Grid & ScrapBook        4.1
# Coloring book moana                                   3.9
# U Launcher Lite – FREE Live Cool Themes, Hide Apps    4.7
# Sketch - Draw & Paint                                 4.5
# Pixel Draw - Number Art Coloring Book                 4.3
#                                                      ...
# Sya9a Maroc - FR                                      4.5
# Fr. Mike Schmitz Audio Teachings                      5.0
# Parkinson Exercices FR                                NaN
# The SCP Foundation DB fr nn5n                         4.5
# iHoroscope - 2018 Daily Horoscope & Astrology         4.5
# Name: Rating, Length: 10841, dtype: float64

# %%
df3 = df3.dropna()

# %%
df3.shape
# Out:
# (9360, 12)

# %%
df3["Installs"] = df3["Installs"].apply(lambda x: x.replace(",", ""))
# Out:
# <ipython-input-49-e38116f66774>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["Installs"] = df3["Installs"].apply(lambda x: x.replace(",", ""))

# %%
df3
# Out:
#                                                                Category  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook           ART_AND_DESIGN
# Coloring book moana                                      ART_AND_DESIGN
# U Launcher Lite – FREE Live Cool Themes, Hide Apps       ART_AND_DESIGN
# Sketch - Draw & Paint                                    ART_AND_DESIGN
# Pixel Draw - Number Art Coloring Book                    ART_AND_DESIGN
# ...                                                                 ...
# FR Calculator                                                    FAMILY
# Sya9a Maroc - FR                                                 FAMILY
# Fr. Mike Schmitz Audio Teachings                                 FAMILY
# The SCP Foundation DB fr nn5n                       BOOKS_AND_REFERENCE
# iHoroscope - 2018 Daily Horoscope & Astrology                 LIFESTYLE
#
#                                                     Rating Reviews  \
# App
# ...

# %%
df3["Installs"] = df3["Installs"].apply(lambda x: x.replace("+", ""))
# Out:
# <ipython-input-51-2cfaeaea3743>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["Installs"] = df3["Installs"].apply(lambda x: x.replace("+", ""))

# %%
df3
# Out:
#                                                                Category  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook           ART_AND_DESIGN
# Coloring book moana                                      ART_AND_DESIGN
# U Launcher Lite – FREE Live Cool Themes, Hide Apps       ART_AND_DESIGN
# Sketch - Draw & Paint                                    ART_AND_DESIGN
# Pixel Draw - Number Art Coloring Book                    ART_AND_DESIGN
# ...                                                                 ...
# FR Calculator                                                    FAMILY
# Sya9a Maroc - FR                                                 FAMILY
# Fr. Mike Schmitz Audio Teachings                                 FAMILY
# The SCP Foundation DB fr nn5n                       BOOKS_AND_REFERENCE
# iHoroscope - 2018 Daily Horoscope & Astrology                 LIFESTYLE
#
#                                                     Rating Reviews  \
# App
# ...

# %%
df3.dtypes
# Out:
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df3["Installs"] = df3["Installs"].apply(lambda x: int(x))
# Out:
# <ipython-input-54-315d66778c4e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["Installs"] = df3["Installs"].apply(lambda x: int(x))

# %%
df3.dtypes
# Out:
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs            int64
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df3.describe()
# Out:
#             Rating      Installs
# count  9360.000000  9.360000e+03
# mean      4.191838  1.790875e+07
# std       0.515263  9.126637e+07
# min       1.000000  1.000000e+00
# 25%       4.000000  1.000000e+04
# 50%       4.300000  5.000000e+05
# 75%       4.500000  5.000000e+06
# max       5.000000  1.000000e+09

# %%
df3
# Out:
#                                                                Category  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook           ART_AND_DESIGN
# Coloring book moana                                      ART_AND_DESIGN
# U Launcher Lite – FREE Live Cool Themes, Hide Apps       ART_AND_DESIGN
# Sketch - Draw & Paint                                    ART_AND_DESIGN
# Pixel Draw - Number Art Coloring Book                    ART_AND_DESIGN
# ...                                                                 ...
# FR Calculator                                                    FAMILY
# Sya9a Maroc - FR                                                 FAMILY
# Fr. Mike Schmitz Audio Teachings                                 FAMILY
# The SCP Foundation DB fr nn5n                       BOOKS_AND_REFERENCE
# iHoroscope - 2018 Daily Horoscope & Astrology                 LIFESTYLE
#
#                                                     Rating Reviews  \
# App
# ...

# %%
df3["Rating"] = df3["Rating"].apply(lambda x: float(x))
# Out:
# <ipython-input-60-3d3ffb0a557c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["Rating"] = df3["Rating"].apply(lambda x: float(x))

# %%
df3.describe()
# Out:
#             Rating       Reviews      Installs
# count  9360.000000  9.360000e+03  9.360000e+03
# mean      4.191838  5.143767e+05  1.790875e+07
# std       0.515263  3.145023e+06  9.126637e+07
# min       1.000000  1.000000e+00  1.000000e+00
# 25%       4.000000  1.867500e+02  1.000000e+04
# 50%       4.300000  5.955000e+03  5.000000e+05
# 75%       4.500000  8.162750e+04  5.000000e+06
# max       5.000000  7.815831e+07  1.000000e+09

# %%
all_size = df3.loc[df3["Rating">4.0], :]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-c7d34e5be031> in <module>
# ----> 1 all_size = df3.loc[df3["Rating">4.0], :]
#
# TypeError: '>' not supported between instances of 'str' and 'float'

# %%
all_size.duplicated()
# Out:
# App
# Photo Editor & Candy Camera & Grid & ScrapBook        False
# Coloring book moana                                   False
# U Launcher Lite – FREE Live Cool Themes, Hide Apps    False
# Sketch - Draw & Paint                                 False
# Pixel Draw - Number Art Coloring Book                 False
#                                                       ...
# FR Calculator                                          True
# Sya9a Maroc - FR                                       True
# Fr. Mike Schmitz Audio Teachings                       True
# The SCP Foundation DB fr nn5n                          True
# iHoroscope - 2018 Daily Horoscope & Astrology          True
# Name: Size, Length: 9360, dtype: bool

# %%
# Out:
# App
# Photo Editor & Candy Camera & Grid & ScrapBook                       19M
# Coloring book moana                                                  14M
# U Launcher Lite – FREE Live Cool Themes, Hide Apps                  8.7M
# Sketch - Draw & Paint                                                25M
# Pixel Draw - Number Art Coloring Book                               2.8M
#                                                              ...
# FR Calculator                                                       2.6M
# Sya9a Maroc - FR                                                     53M
# Fr. Mike Schmitz Audio Teachings                                    3.6M
# The SCP Foundation DB fr nn5n                         Varies with device
# iHoroscope - 2018 Daily Horoscope & Astrology                        19M
# Name: Size, Length: 9360, dtype: object

# %%
df3["Size"] = df3["Size"].apply(lambda x: x.replace("k", "000"))
# Out:
# <ipython-input-75-dfbba1c00c4a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["Size"] = df3["Size"].apply(lambda x: x.replace("k", "000"))

# %%
df3["Size"] = df3["Size"].apply(lambda x: x.replace("M", "000000"))
# Out:
# <ipython-input-71-dd6e10932493>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["Size"] = df3["Size"].apply(lambda x: x.replace("M", "000000"))

# %%
df3["Size"] = df3["Size"].apply(lambda x: x.replace("Varies with device", "0"))
# Out:
# <ipython-input-72-f97bf7358aa3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["Size"] = df3["Size"].apply(lambda x: x.replace("Varies with device", "0"))

# %%
df3["Size"] = df3["Size"].apply(lambda x: float(x))
# Out:
# <ipython-input-76-adc6996d4519>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["Size"] = df3["Size"].apply(lambda x: float(x))

# %%
df3.describe()
# Out:
#             Rating       Reviews          Size      Installs
# count  9360.000000  9.360000e+03  9.360000e+03  9.360000e+03
# mean      4.191838  5.143767e+05  1.741184e+07  1.790875e+07
# std       0.515263  3.145023e+06  2.400851e+07  9.126637e+07
# min       1.000000  1.000000e+00  0.000000e+00  1.000000e+00
# 25%       4.000000  1.867500e+02  2.900000e+00  1.000000e+04
# 50%       4.300000  5.955000e+03  4.685000e+05  5.000000e+05
# 75%       4.500000  8.162750e+04  2.700000e+07  5.000000e+06
# max       5.000000  7.815831e+07  1.000000e+08  1.000000e+09

# %%
df3
# Out:
#                                                                Category  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook           ART_AND_DESIGN
# Coloring book moana                                      ART_AND_DESIGN
# U Launcher Lite – FREE Live Cool Themes, Hide Apps       ART_AND_DESIGN
# Sketch - Draw & Paint                                    ART_AND_DESIGN
# Pixel Draw - Number Art Coloring Book                    ART_AND_DESIGN
# ...                                                                 ...
# FR Calculator                                                    FAMILY
# Sya9a Maroc - FR                                                 FAMILY
# Fr. Mike Schmitz Audio Teachings                                 FAMILY
# The SCP Foundation DB fr nn5n                       BOOKS_AND_REFERENCE
# iHoroscope - 2018 Daily Horoscope & Astrology                 LIFESTYLE
#
#                                                     Rating  Reviews  \
# App
# ...

# %%
df3.loc[(df3["Rating"]>4.5) & (df3["Rating"]<=4.8), :]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-107-4bf223470a74> in <module>
# ----> 1 df3.loc[df3["App".contain("Kid")], :]
#
# AttributeError: 'str' object has no attribute 'contain'

# %%
df3[df3['Category'].str.contains("ART")]
# Out:
#                                                           Category  Rating  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook      ART_AND_DESIGN     4.1
# Coloring book moana                                 ART_AND_DESIGN     3.9
# U Launcher Lite – FREE Live Cool Themes, Hide Apps  ART_AND_DESIGN     4.7
# Sketch - Draw & Paint                               ART_AND_DESIGN     4.5
# Pixel Draw - Number Art Coloring Book               ART_AND_DESIGN     4.3
# ...                                                            ...     ...
# AJ Styles Wallpaper 2018 - AJ Styles HD Wallpaper   ART_AND_DESIGN     4.0
# Fantasy theme dark bw black building                ART_AND_DESIGN     4.8
# Dp for girls                                        ART_AND_DESIGN     4.2
# Name Art DP - Focus n Filter Text 2018              ART_AND_DESIGN     4.3
# Spring flowers theme couleurs d t space             ART_AND_DESIGN     5.0
#
# ...

# %%
df3[df3.index.str.contains("Kid", case=False)]
# Out:
#                                                           Category  Rating  \
# App
# Kids Paint Free - Drawing Fun                       ART_AND_DESIGN     4.7
# Chat Kids - Chat Room For Kids                              DATING     4.7
# Chat Kids - Chat Room For Kids                              DATING     4.7
# Kids Mode                                                EDUCATION     3.8
# PBS KIDS Video                                           EDUCATION     4.2
# ...                                                            ...     ...
# Messenger Kids – Safer Messaging and Video Chat             FAMILY     4.2
# FirstCry Baby & Kids Shopping, Fashion & Parenting        SHOPPING     4.1
# PBS KIDS Games                                              FAMILY     4.3
# Cake Shop - Kids Cooking                                    FAMILY     4.3
# Fun Kid Racing - Motocross                                  FAMILY     4.1
#
# ...
